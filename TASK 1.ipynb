# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math as math
import seaborn as sns

# %%
#1->data loading and cleaning

# %%
import pandas as pd

# File path to the CSV
file_path = r"C:\Users\SURAJ RAIKAR\Desktop\doc.csv"

# Load the CSV file into a DataFrame
df = pd.read_csv(file_path)

# Display the entire dataset
# In Jupyter, this displays all rows and columns without truncation
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns

# Print the full dataset
print("Full Dataset:")
print(df)

# Reset the display options if needed
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
# Out:
# Full Dataset:
#      Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0                 1  24-11-2023     CUST001    Male   34           Beauty
# 1                 2  27-02-2023     CUST002  Female   26         Clothing
# 2                 3  13-01-2023     CUST003    Male   50      Electronics
# 3                 4  21-05-2023     CUST004    Male   37         Clothing
# 4                 5  06-05-2023     CUST005    Male   30           Beauty
# 5                 6  25-04-2023     CUST006  Female   45           Beauty
# 6                 7  13-03-2023     CUST007    Male   46         Clothing
# 7                 8  22-02-2023     CUST008    Male   30      Electronics
# 8                 9  13-12-2023     CUST009    Male   63      Electronics
# 9                10  07-10-2023     CUST010  Female   52         Clothing
# 10               11  14-02-2023     CUST011    Male   23         Clothing
# ...

# %%
# Importing the csv library
import csv

# Corrected file path
file_path = r"C:\Users\SURAJ RAIKAR\Desktop\doc.csv"  # Use raw string or double backslashes

# Opening the CSV file
with open(file_path, mode='r') as csv_file:

    # Creating an object of CSV reader with delimiter as ','
    csv_reader = csv.reader(csv_file, delimiter=',')

    # List to store the names of columns
    list_of_column_names = []

    # Loop to iterate through the rows of CSV
    for row in csv_reader:
        # Adding the first row (header)
        list_of_column_names.append(row)

        # Breaking the loop after the first iteration itself
        break

# Printing the result
print("List of column names:", list_of_column_names[0])
# Out:
# List of column names: ['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age', 'Product Category', 'Quantity', 'Price per Unit', 'Total Amount']

# %%
import pandas as pd

# Correct the file path (use raw string or double backslashes)
file_path = r"C:\Users\SURAJ RAIKAR\Desktop\doc.csv"

# Read the CSV file
data = pd.read_csv(file_path, index_col=False)

# Create a DataFrame
df = pd.DataFrame(data)

# Reset the index (if needed)
df = df.reset_index(drop=True)

print("Data imported successfully!")
print(df.head())
# Out:
# Data imported successfully!
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  24-11-2023     CUST001    Male   34           Beauty
# 1               2  27-02-2023     CUST002  Female   26         Clothing
# 2               3  13-01-2023     CUST003    Male   50      Electronics
# 3               4  21-05-2023     CUST004    Male   37         Clothing
# 4               5  06-05-2023     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
#2->descriptive statistics

# %%
print("Total sales: {}".format(df["Quantity"].sum()))
print("Total profit: {}".format(df["Total Amount"].sum()))
# Out:
# Total sales: 2514
# Total profit: 456000

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount'],
#       dtype='object')

# %%
print("mean average of total amount = {}".format(df["Total Amount"].mean()))
print("median average of total amount = {}".format(df["Total Amount"].median()))
print("mode of total amount = {}".format(df["Total Amount"].mode()))
# Out:
# mean average of total amount = 456.0
# median average of total amount = 135.0
# mode of total amount = 0    50
# Name: Total Amount, dtype: int64

# %%
df.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
#3->time series analysis

# %%
sns.relplot(data=df['Total Amount'],kind='scatter')

# %%
#4->Customer and Product Analysis
#5->Visualization

# %%
df['Product Category'].value_counts()
# Out:
# Product Category
# Clothing       351
# Electronics    342
# Beauty         307
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Product Category'])
# Out:
# <Axes: xlabel='Product Category', ylabel='count'>

# %%
sns.pairplot(data=df,hue="Product Category")

# %%
grp = df.groupby("Product Category")[["Quantity","Total Amount"]].sum()
print(grp)
# Out:
#                   Quantity  Total Amount
# Product Category
# Beauty                 771        143515
# Clothing               894        155580
# Electronics            849        156905

# %%
cat = df["Product Category"].value_counts()
cat
# Out:
# Product Category
# Clothing       351
# Electronics    342
# Beauty         307
# Name: count, dtype: int64

# %%
grp.plot(kind='bar',figsize=(12,5))
plt.title("Quanitity v/s total amount")
plt.ylabel("Quantity and Total amount")
plt.show()

# %%
colour_list = ["red","green","blue"]
cat.plot(kind='pie',figsize=(16,7))
plt.title("pie chart of product category")
plt.axis("equal")
plt.show()

# %%
gen = df['Gender'].value_counts()
gen
# Out:
# Gender
# Female    510
# Male      490
# Name: count, dtype: int64

# %%
gen.plot(kind="pie",figsize=(12,5),shadow=True, labels=None,colors=["orange","skyblue"])
gender_list = ['Female', 'Male']
plt.title("pie chart of gender")
plt.axis("equal")
plt.legend(labels=gender_list,loc="upper right")
plt.show()

# %%
df["Price per Unit"].corr(df["Total Amount"])
# Out:
# 0.8519248403554025

# %%
sns.lineplot(x="Price per Unit",y="Total Amount",data=df)
plt.show()

# %%
#6->Recommendations: Provide actionable recommendations based on the EDA

# %%
 Actionable Recommendations:
1.Segment customers by demographics (age, income, gender) for targeted marketing.
2.Reward high-value customers with personalized offers or VIP programs.
3.Optimize product offerings based on the sales performance of product categories.
4.Re-engage dormant customers with special offers or incentives.
5.Target specific demographic groups for tailored product recommendations and promotions.
6.Plan marketing campaigns around seasonal trends or sales spikes.
7.Utilize income-based pricing strategies to cater to different customer budgets.
8.Use data to recommend personalized products based on customer preferences and purchase history.
9.Implement cross-sell and upsell strategies to increase average order value.
10.Optimize marketing channels based on customer age and behavior (e.g., social media for younger audiences).

These recommendations are aimed at improving customer retention, increasing sales, and making your marketing efforts more efficient and personalized based on customer insights derived from the EDA.
